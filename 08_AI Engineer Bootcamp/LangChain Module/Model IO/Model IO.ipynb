# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
pip install langchain langchain-groq groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
import groq
from langchain_groq import ChatGroq
import os

# %%
chat = ChatGroq(
    model_name="llama-3.1-8b-instant",   # Correct Groq model name
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
prompt = "I've recently adopted a dog. Could you suggest some dog names?"

response = chat.invoke(prompt)

print(response.content)
# Out:
# Congratulations on adopting a new furry family member.  I'd be happy to help you find the perfect name for your dog. Here are some popular and unique name suggestions:
#
# **Male Dog Names:**
#
# 1. Max
# 2. Charlie
# 3. Buddy
# 4. Cooper
# 5. Rocky
# 6. Duke
# 7. Bear
# 8. Oliver
# 9. Finn
# 10. Jasper
# 11. Archie
# 12. Bentley
# 13. Hunter
# 14. Milo
# 15. Gus
#
# **Female Dog Names:**
#
# 1. Luna
# 2. Bella
# 3. Lucy
# 4. Daisy
# 5. Gracie
# 6. Sadie
# 7. Maggie
# 8. Abbie
# 9. Sophie
# 10. Zoe
# 11. Lola
# 12. Coco
# 13. Ginger
# 14. Fiona
# 15. Willow
#
# **Unique Dog Names:**
#
# 1. Sage
# 2. Orion
# 3. Piper
# 4. Remi
# 5. Indie
# 6. Clio
# 7. Bronson
# 8. Lyra
# 9. Caspian
# 10. Wren
#
# **Consider Your Dog's Breed, Size, and Personality:**
#
# * If your dog is a large breed, consider strong and powerful names like Atlas or Zeus.
# * If your dog is a small breed, consider cute and playful names like Mochi or Peanut.
# ...
