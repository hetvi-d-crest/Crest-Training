# %%
pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-8.1.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pinecone) (2026.1.4)
# Collecting orjson>=3.11.6 (from pinecone)
#   Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting pinecone-plugin-assistant<4.0.0,>=3.0.1 (from pinecone)
#   Downloading pinecone_plugin_assistant-3.0.3-py3-none-any.whl.metadata (30 kB)
# Collecting pinecone-plugin-interface<0.1.0,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pinecone) (2.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hetvidesai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hetvidesai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.11)
# Requirement already satisfied: six>=1.5 in c:\users\hetvidesai\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Downloading pinecone-8.1.1-py3-none-any.whl (742 kB)
#    ---------------------------------------- 0.0/742.8 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/742.8 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 742.8/742.8 kB 3.2 MB/s  0:00:00
# Downloading pinecone_plugin_assistant-3.0.3-py3-none-any.whl (280 kB)
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl (127 kB)
# Installing collected packages: pinecone-plugin-interface, orjson, pinecone-plugin-assistant, pinecone
#
#    -------------------- ------------------- 2/4 [pinecone-plugin-assistant]
#    -------------------- ------------------- 2/4 [pinecone-plugin-assistant]
#    -------------------- ------------------- 2/4 [pinecone-plugin-assistant]
#    -------------------- ------------------- 2/4 [pinecone-plugin-assistant]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ------------------------------ --------- 3/4 [pinecone]
#    ---------------------------------------- 4/4 [pinecone]
#
# Successfully installed orjson-3.11.8 pinecone-8.1.1 pinecone-plugin-assistant-3.0.3 pinecone-plugin-interface-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec
import os

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
pc = Pinecone(api_key = os.environ.get("PINECONE_API_KEY"), environment = os.environ.get("PINECONE_ENV"))

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "my-index",
#         "metric": "cosine",
#         "host": "my-index-rc40est.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "text"
#             },
#             "dimension": 1024,
#             "metric": "cosine",
#             "write_parameters": {
#                 "dimension": 1024,
#                 "input_type": "passage",
#                 "truncate": "END"
#             },
#             "read_parameters": {
#                 "dimension": 1024,
#                 "input_type": "query",
#                 "truncate": "END"
#             },
#             "vector_type": "dense"
#         }
#     }
# ]
