# %% [raw]
# 1. Memory View on Bytes Object
#
# Write a Python program that creates a memory view on a bytes object and prints the length and first 8 bytes.

# %%
def main():
    try:
        byte_obj = b"Python Programming!"
        memorydata = memoryview(byte_obj)
        print("The memory data: ", memorydata)
        print("Length of the memory data : ", len(memorydata))
        print("First 8 bytes: ", memorydata[:8])
    except Exception as e:
        print("An exception occured!", e)

if __name__ == '__main__':
    main()
# Out:
# The memory data:  <memory at 0x000001E1C7E91840>
# Length of the memory data :  19
# First 8 bytes:  <memory at 0x000001E1C7E919C0>
