# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Guessing Game Challenge
#
# Let's use `while` loops to create a guessing game.
#
# The Challenge:
#
# Write a program that picks a random integer from 1 to 100, and has players guess the number. The rules are:
#
# 1. If a player's guess is less than 1 or greater than 100, say "OUT OF BOUNDS"
# 2. On a player's first turn, if their guess is
#  * within 10 of the number, return "WARM!"
#  * further than 10 away from the number, return "COLD!"
# 3. On all subsequent turns, if a guess is
#  * closer to the number than the previous guess return "WARMER!"
#  * farther from the number than the previous guess, return "COLDER!"
# 4. When the player's guess equals the number, tell them they've guessed correctly *and* how many guesses it took!
#
# You can try this from scratch, or follow the steps outlined below. A separate Solution notebook has been provided. Good luck!

# %% [markdown]
# #### First, pick a random integer from 1 to 100 using the random module and assign it to a variable
#
# Note: `random.randint(a,b)` returns a random integer in range `[a, b]`, including both end points.

# %%
import random
randomNumber = random.randint(1,100)
print(randomNumber)
# Out:
# 60

# %% [markdown]
# #### Next, print an introduction to the game and explain the rules

# %%
print("The game is to guess the random number. Your task is to guess in minimum try possible.")
print("If you are not in the range it will give you OUT OF BOUNDS")
print("On your first turn:")
print("  If you are within +- 10 range it will give you WARM!")
print("  If you move away from +- 10 ranges of the number it will give you COLD!")
print("On all subsequent turns:")
print("  If you move closer to the number than the previous guess it will give you WARMER!")
print("  If you move farther to the number than the previous guess it will give you COLDER!")
# Out:
# The game is to guess the random number. Your task is to guess in minimum try possible.
# If you are not in the range it will give you OUT OF BOUNDS
# On your first turn:
#   If you are within +- 10 range it will give you WARM!
#   If you move away from +- 10 ranges of the number it will give you COLD!
# On all subsequent turns:
#   If you move closer to the number than the previous guess it will give you WARMER!
#   If you move farther to the number than the previous guess it will give you COLDER!

# %% [markdown]
# #### Create a list to store guesses
#
# Hint: zero is a good placeholder value. It's useful because it evaluates to "False"

# %%
gusses = []

# %% [markdown]
# #### Write a `while` loop that asks for a valid guess. Test it a few times to make sure it works.

# %%
while True:
    guess = int(input("What is your guess?  Hint: Most likely less than 3 digit number!"))

    if 1 <= guess <= 100:
        break
    else:
        print("Your guess is : OUT OF BOUNDS")
        continue
# Out:
# What is your guess?  Hint: Most likely less than 3 digit number! 101
# Your guess is : OUT OF BOUNDS
# What is your guess?  Hint: Most likely less than 3 digit number! -8
# Your guess is : OUT OF BOUNDS
# What is your guess?  Hint: Most likely less than 3 digit number! 0
# Your guess is : OUT OF BOUNDS
# What is your guess?  Hint: Most likely less than 3 digit number! 3

# %% [markdown]
# #### Write a `while` loop that compares the player's guess to our number. If the player guesses correctly, break from the loop. Otherwise, tell the player if they're warmer or colder, and continue asking for guesses.
#
# Some hints:
# * it may help to sketch out all possible combinations on paper first!
# * you can use the `abs()` function to find the positive difference between two numbers
# * if you append all new guesses to the list, then the previous guess is given as `guesses[-2]`

# %%
import random
randomNumber = random.randint(1,100)
print(randomNumber)

gusses = []
while True:
    guess = int(input("What is your guess?  Hint: Most likely less than 3 digit number!"))

    if guess < 1 or guess > 100:
        print("OUT OF BOUNDS! Try again!")
        continue
    else:
        gusses.append(guess)

    if guess == randomNumber:
        print("YOU GUESSED IT RIGHT IN " + str(len(gusses)) + " TRYS")
        break

    if len(gusses) >= 2:
        if abs(guess-randomNumber) < abs(gusses[-2]-randomNumber):
            print("WARMWER!")
        else:
            print("COLDER!")

    else:
        if randomNumber-10 <= guess <= randomNumber +10:
            print("Your first guess is : WARM!")
        else:
            print("Your first guess is COLD!")
# Out:
# 27
# What is your guess?  Hint: Most likely less than 3 digit number! 90
# Your first guess is COLD!
# What is your guess?  Hint: Most likely less than 3 digit number! 99
# COLDER!
# What is your guess?  Hint: Most likely less than 3 digit number! 80
# WARMWER!
# What is your guess?  Hint: Most likely less than 3 digit number! 40
# WARMWER!
# What is your guess?  Hint: Most likely less than 3 digit number! 20
# WARMWER!
# What is your guess?  Hint: Most likely less than 3 digit number! 2
# COLDER!
# What is your guess?  Hint: Most likely less than 3 digit number! 27
# YOU GUESSED IT RIGHT IN 7 TRYS

# %% [markdown]
# That's it! You've just programmed your first game!
#
# In the next section we'll learn how to turn some of these repetitive actions into *functions* that can be called whenever we need them.

# %% [markdown]
# ### Good Job!
