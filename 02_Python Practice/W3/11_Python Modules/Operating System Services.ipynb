# %% [raw]
# 1. OS Info and Directory Listing
#
# Write a Python program to get the name of the operating system (Platform independent), information of the current operating system, current working directory, print files and directories in the current directory, and raise errors if the path or file name is invalid.

# %%
import os

print("Operating System : ", os.name)
print("Current working directory: ", os.getcwd())
# Out:
# Operating System :  nt
# Current working directory:  C:\Users\HetviDesai\Documents\Crest Training\02_Python Practice\W3\10_Python Modules

# %%
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', 'Builtin modules.ipynb', 'Operating System Services.ipynb']

# %%
try:
    filename = 'input.txt'
    file = open(filename, 'r')
    text = file.read()
    file.close()
except IOError:
    print("File not opened")
# Out:
# File not opened

# %% [raw]
# 2. List Directories and Files
#
# Write a Python program to list only directories, files and all directories, files in a specified path.

# %%
path = r'C:\Users\HetviDesai\Documents\Crest Training\02_Python Practice\W3'
print("Only directories: ")
print([ name for name in os.listdir(path) if os.path.isdir(os.path.join(path, name)) ])
print("Only files: ")
print([ name for name in os.listdir(path) if not os.path.isdir(os.path.join(path, name)) ])
print("All files and directories : ")
print([name for name in os.listdir(path)])
# Out:
# Only directories:
# ['.ipynb_checkpoints', '01_Python Basics', '02_Python Advanced', '03_Python Control Flow', '04_Python Data Types', '05_Python Concepts', '06_Functional Programming', '07_Date and Time', '08_File Handling', '09_Advanced Python Data Types', '10_Concurrency and Threading', '10_Python Modules']
# Only files:
# []
# All files and directories :
# ['.ipynb_checkpoints', '01_Python Basics', '02_Python Advanced', '03_Python Control Flow', '04_Python Data Types', '05_Python Concepts', '06_Functional Programming', '07_Date and Time', '08_File Handling', '09_Advanced Python Data Types', '10_Concurrency and Threading', '10_Python Modules']
