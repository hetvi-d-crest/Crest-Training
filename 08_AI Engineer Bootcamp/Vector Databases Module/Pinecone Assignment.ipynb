# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec
import os
from dotenv import load_dotenv, find_dotenv

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
pc = Pinecone(api_key = os.environ.get("PINECONE_API_KEY"), environment = os.environ.get("PINECONE_ENV"))

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "my-index",
#         "metric": "cosine",
#         "host": "my-index-rc40est.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "text"
#             },
#             "dimension": 1024,
#             "metric": "cosine",
#             "write_parameters": {
#                 "dimension": 1024,
#                 "input_type": "passage",
#                 "truncate": "END"
#             },
#             "read_parameters": {
#                 "dimension": 1024,
#                 "input_type": "query",
#                 "truncate": "END"
#             },
#             "vector_type": "dense"
#         }
#     }
# ]

# %%
index_name = "my-index"
dimension = 3
metric = "cosine"

# %%
if index_name in [index.name for index in pc.list_indexes()]:
    pc.delete_index(index_name)
    print(f"{index_name} succesfully deleted.")
else:
     print(f"{index_name} not in index list.")
# Out:
# my-index succesfully deleted.

# %%
pc.list_indexes()
# Out:
# []

# %%
pc.create_index(
    name = index_name, 
    dimension = dimension, 
    metric = metric, 
    spec = ServerlessSpec(
        cloud = "aws", 
        region = "us-east-1")
    )
# Out:
# {
#     "name": "my-index",
#     "metric": "cosine",
#     "host": "my-index-rc40est.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "e2e08f4c4d338a3284b67209b2850857",
#             "date": "Fri, 03 Apr 2026 11:15:51 GMT",
#             "server": "Google Frontend",
#             "content-length": "383",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "my-index",
#         "metric": "cosine",
#         "host": "my-index-rc40est.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
# create an index
index_name_2 = "my-index-2"
dimension_2 = 1536
metric_2 = "euclidean"

# %%
# if index exist, delete it
if index_name_2 in [index.name for index in pc.list_indexes()]:
    pc.delete_index(index_name_2)
    print(f"{index_name_2} succesfully deleted.")
else:
    print(f"{index_name_2} not in index list.")
# Out:
# my-index-2 not in index list.

# %%
pc
pc.create_index(
    name=index_name_2,
    dimension=dimension_2,
    metric=metric_2,
    spec=ServerlessSpec(
        cloud='aws',
        region='us-east-1'
    )
)
# Out:
# {
#     "name": "my-index-2",
#     "metric": "euclidean",
#     "host": "my-index-2-rc40est.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "b0aa5755319fa7a1c9757e0b9666e349",
#             "date": "Fri, 03 Apr 2026 11:16:20 GMT",
#             "server": "Google Frontend",
#             "content-length": "393",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "my-index-2",
#         "metric": "euclidean",
#         "host": "my-index-2-rc40est.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "my-index",
#         "metric": "cosine",
#         "host": "my-index-rc40est.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
index = pc.Index(name = index_name)

# %%
index.upsert([
    ('Dog', [4.,0.,1.]),
    ('Cat', [4.,0.,1.]),
    ('Chicken', [2.,2.,1.]),
    ('Mantis', [6.,2.,3.]),
    ('Elephant', [4.,0.,1.]),
])
# Out:
# UpsertResponse(upserted_count=5, _response_info={'raw_headers': {'date': 'Fri, 03 Apr 2026 11:19:55 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '87', 'x-pinecone-request-latency-ms': '285', 'x-envoy-upstream-service-time': '285', 'x-pinecone-response-duration-ms': '287', 'grpc-status': '0', 'server': 'envoy'}})
