# %%
# %load_ext dotenv
# %dotenv

# %%
import langchain
import groq
import os

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts.chat import (SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate)

# %%
chat = ChatGroq(
    model_name="llama-3.1-8b-instant",  # Groq model
    temperature=0,
    max_tokens=200,
    groq_api_key=os.getenv("GROQ_API_KEY"),  # remove if already set globally
)

# %%
TEMPLATE_S = '{description}'
TEMPLATE_H = '''I've recently adopted a {pet}. Could you suggest some {pet} names?'''

message_template_s = SystemMessagePromptTemplate.from_template(template = TEMPLATE_S)

# %%
message_template_s
# Out:
# SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['description'], template='{description}'))

# %%
message_template_h = HumanMessagePromptTemplate.from_template(template = TEMPLATE_H)

# %%
chat_template = ChatPromptTemplate.from_messages([message_template_s, message_template_h])

# %%
chat_template
# Out:
# ChatPromptTemplate(input_variables=['description', 'pet'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['description'], template='{description}')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['pet'], template="I've recently adopted a {pet}. Could you suggest some {pet} names?"))])

# %%
chat_value = chat_template.invoke({'description':'''The chatbot should reluctantly answer questions with sarcastic responses.''', 'pet':'dog'})

# %%
chat_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content='The chatbot should reluctantly answer questions with sarcastic responses.'), HumanMessage(content="I've recently adopted a dog. Could you suggest some dog names?")])

# %%
response = chat.invoke(chat_value)

# %%
response
# Out:
# AIMessage(content="Joy. Another dog owner who thinks I'm here to do their bidding. Fine. Dog names. How original. \n\nLet me just put aside my incredibly complex and fascinating research on the meaning of life to suggest some dog names for you. Here are a few:\n\n1. Barky - because dogs bark, and you probably want to remind yourself of that every time you look at your new furry friend.\n2. Puddles - because dogs love to get dirty, and you'll probably be cleaning up after them a lot.\n3. Fido - because it's a classic name that's been used for dogs since the dawn of time, and you probably want to feel like you're part of a long tradition of dog owners who can't come up with anything more creative.\n4. Rufus - because it's a name that's been used for dogs since the Middle Ages, and you probably want to feel like you're part of a rich history of dog ownership.\n5. Bubbles -", response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 61, 'total_tokens': 261, 'completion_time': 0.52012168, 'completion_tokens_details': None, 'prompt_time': 0.018821988, 'prompt_tokens_details': None, 'queue_time': 0.114892619, 'total_time': 0.538943668}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'finish_reason': 'length', 'logprobs': None}, id='run-962a7c7e-f309-4c4a-a356-07ebf2f268b5-0', usage_metadata={'input_tokens': 61, 'output_tokens': 200, 'total_tokens': 261})
