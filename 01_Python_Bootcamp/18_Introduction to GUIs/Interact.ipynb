# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

def func(x):
    return x

# %%
interact(func, x = 10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.func(x)>

# %%
interact(func, x = (-10, 10, 1))
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=10, min=-10), Output()), _dom_classes=('widget-i…
# <function __main__.func(x)>

# %%
interact(func, x = ['one', 'two', 'three'])
# Out:
# interactive(children=(Dropdown(description='x', options=('one', 'two', 'three'), value='one'), Output()), _dom…
# <function __main__.func(x)>

# %%
interact(func, x={1:'one', 2:'two', 3:'three'})
# Out:
# interactive(children=(Dropdown(description='x', options={1: 'one', 2: 'two', 3: 'three'}, value='one'), Output…
# <function __main__.func(x)>

# %%
interact(func, x = True)
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.func(x)>

# %%
interact(func, x = "Hello")
# Out:
# interactive(children=(Text(value='Hello', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.func(x)>

# %%
def h(p, q):
    return (p,q)

interact(h, p=5, q=fixed(20))
# Out:
# interactive(children=(IntSlider(value=5, description='p', max=15, min=-5), Output()), _dom_classes=('widget-in…
# <function __main__.h(p, q)>

# %%
from IPython.display import display

def func(x,y):
    display(x+y)
    return x+y

w = interactive(func, x=(-10, 10, 1), y=(-20, 20, 2))

type(w)
# Out:
# ipywidgets.widgets.interaction.interactive

# %%
w.children
# Out:
# (IntSlider(value=0, description='x', max=10, min=-10),
#  IntSlider(value=0, description='y', max=20, min=-20, step=2),
#  Output())

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=10, min=-10), IntSlider(value=0, description='y'…

# %%
w.kwargs
# Out:
# {'x': 0, 'y': 0}

# %%
w.result
# Out:
# 0

# %%
a= widgets.FloatText()
b= widgets.FloatSlider()

display(a, b)
mylink = widgets.jslink((a, 'value'), (b, 'value'))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
mylink.unlink()

# %%
for item in widgets.Widget.widget_types.items():
    print(item[0][2][:-5])
# Out:
# Layout
# Accordion
# Audio
# BoundedFloatText
# BoundedIntText
# Box
# Button
# ButtonStyle
# Checkbox
# CheckboxStyle
# ColorPicker
# ColorsInput
# Combobox
# ControllerAxis
# ControllerButton
# Controller
# DOMWidget
# DatePicker
# Datetime
# DescriptionStyle
# DirectionalLink
# Dropdown
# FileUpload
# FloatLogSlider
# FloatProgress
# FloatRangeSlider
# FloatSlider
# FloatText
# FloatsInput
# GridBox
# HBox
# HTMLMath
# HTMLMathStyle
# HTML
# HTMLStyle
# Image
# IntProgress
# IntRangeSlider
# IntSlider
# IntText
# IntsInput
# Label
# LabelStyle
# Link
# NaiveDatetime
# Password
# Play
# ProgressStyle
# RadioButtons
# Select
# SelectMultiple
# SelectionRangeSlider
# SelectionSlider
# SliderStyle
# Stack
# Tab
# TagsInput
# Text
# TextStyle
# Textarea
# Time
# ToggleButton
# ToggleButtonStyle
# ToggleButtons
# ToggleButtonsStyle
# VBox
# Valid
# Video
# Output
# C:\Users\HetviDesai\AppData\Local\Temp\ipykernel_12004\293324014.py:1: DeprecationWarning: Widget.widget_types is deprecated.
#   for item in widgets.Widget.widget_types.items():

# %%
widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
# Out:
# IntSlider(value=7, continuous_update=False, description='Test:', max=10)

# %%
widgets.FloatSlider(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatSlider(value=7.5, continuous_update=False, description='Test:', max=10.0, orientation='vertical', readout…

# %%
widgets.IntRangeSlider(
    value=[5, 7],
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)
# Out:
# IntRangeSlider(value=(5, 7), continuous_update=False, description='Test:', max=10)

# %%
widgets.IntProgress(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Loading:',
    bar_style='', # 'success', 'info', 'warning', 'danger' or ''
    orientation='horizontal'
)
# Out:
# IntProgress(value=7, description='Loading:', max=10)

# %%
widgets.BoundedIntText(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Text:',
    disabled=False
)
# Out:
# BoundedIntText(value=7, description='Text:', max=10)

# %%
widgets.IntText(
    value=7,
    description='Any:',
    disabled=False
)
# Out:
# IntText(value=7, description='Any:')

# %%
widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
# Out:
# ToggleButton(value=False, description='Click me', icon='check', tooltip='Description')

# %%
widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False
)
# Out:
# Checkbox(value=False, description='Check me')

# %%
widgets.Valid(
    value=False,
    description='Valid!',
)
# Out:
# Valid(value=False, description='Valid!')

# %%
widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')

# %%
widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
    # value='pineapple',
    description='Pizza topping:',
    disabled=False
)
# Out:
# RadioButtons(description='Pizza topping:', options=('pepperoni', 'pineapple', 'anchovies'), value='pepperoni')

# %%
widgets.Select(
    options=['Linux', 'Windows', 'OSX'],
    value='OSX',
    # rows=10,
    description='OS:',
    disabled=False
)
# Out:
# Select(description='OS:', index=2, options=('Linux', 'Windows', 'OSX'), value='OSX')

# %%
widgets.SelectionSlider(
    options=['scrambled', 'sunny side up', 'poached', 'over easy'],
    value='sunny side up',
    description='I like my eggs ...',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True
)
# Out:
# SelectionSlider(continuous_update=False, description='I like my eggs ...', index=1, options=('scrambled', 'sun…

# %%
widgets.HTML(
    value="Hello <b>World</b>",
    placeholder='Some HTML',
    description='Some HTML',
)
# Out:
# HTML(value='Hello <b>World</b>', description='Some HTML', placeholder='Some HTML')

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.layout.margin = 'auto'
w.layout.height = '75px'

# %%
x = widgets.IntSlider(value=15,description='New slider')
display(x)
# Out:
# IntSlider(value=15, description='New slider')

# %%
widgets.Button(description='Danger Button', button_style='danger')
# Out:
# Button(button_style='danger', description='Danger Button', style=ButtonStyle())
