# %%
def func():
    return 1

# %%
func()
# Out:
# 1

# %%
s = 'Global Variable'

def check_for_locals():
    print(locals())

check_for_locals()
# Out:
# {}

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def func():\n    return 1', 'func()', "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())", 'print(globals())', 'print(globals.keys())', 'print(globals().keys())', "globals()['s']", "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())\n\ncheck_for_locals()", 'print(globals())'], '_oh': {2: 1, 7: 'Global Variable'}, '_dh': [WindowsPath('C:/Users/HetviDesai/Documents/Crest Training/01_Python_Bootcamp/10_Python Decorators')], 'In': ['', 'def func():\n    return 1', 'func()', "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())", 'print(globals())', 'print(globals.keys())', 'print(globals().keys())', "globals()['s']", "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())\n\ncheck_for_locals()", 'print(globals())'], 'Out': {2: 1, 7: 'Global Variable'}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000208CA7EF770>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000208CA879160>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000208CA879160>, 'open': <function open at 0x00000208C8542660>, '_': 'Global Variable', '__': 1, '___': '', '__session__': 'C:\\Users\\HetviDesai\\Documents\\Crest Training\\01_Python_Bootcamp\\10_Python Decorators\\Untitled.ipynb', '_i': "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())\n\ncheck_for_locals()", '_ii': "globals()['s']", '_iii': 'print(globals().keys())', '_i1': 'def func():\n    return 1', 'func': <function func at 0x00000208CAA013A0>, '_i2': 'func()', '_2': 1, '_i3': "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())", 's': 'Global Variable', 'check_for_locals': <function check_for_locals at 0x00000208CAFC72E0>, '_i4': 'print(globals())', '_i5': 'print(globals.keys())', '_i6': 'print(globals().keys())', '_i7': "globals()['s']", '_7': 'Global Variable', '_i8': "s = 'Global Variable'\n\ndef check_for_locals():\n    print(locals())\n\ncheck_for_locals()", '_i9': 'print(globals())'}

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'func', '_i2', '_2', '_i3', 's', 'check_for_locals', '_i4', '_i5', '_i6', '_i7', '_7', '_i8', '_i9', '_i10'])

# %%
globals()['s']
# Out:
# 'Global Variable'

# %%
def hello(name='Jose'):
    return 'Hello '+name

hello()
# Out:
# 'Hello Jose'

# %%
def new_decorator(func):

    def wrap_func():
        print("Code would be here, before executing the func")

        func()

        print("Code here will execute after the func()")

    return wrap_func

# %%
@new_decorator
def func_needs_decorator():
    print("This func is in need of a decorator")

# %%
func_needs_decorator()
# Out:
# Code would be here, before executing the func
# This func is in need of a decorator
# Code here will execute after the func()
