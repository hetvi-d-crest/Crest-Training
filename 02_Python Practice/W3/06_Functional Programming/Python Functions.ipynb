# %% [raw]
# 1. Maximum of Three Numbers
#
# Write a Python function to find the maximum of three numbers.

# %%
def findMax(a,b,c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c

findMax(1, 2,3)
# Out:
# 3

# %%
findMax(2, 6, -3)
# Out:
# 6

# %%
findMax(0,0, -9)
# Out:
# 0
