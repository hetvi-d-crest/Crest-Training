# %%
pip show langchain
# Out:
# Name: langchain
# Version: 0.2.8
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages
# Requires: aiohttp, async-timeout, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext dotenv
# %dotenv
# Out:
# cannot find .env file

# %%
# %pip install -U langchain-chroma
# Out:
# Requirement already satisfied: langchain-chroma in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (1.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-chroma) (1.5.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-chroma) (1.2.24)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.2)
# Requirement already satisfied: pydantic>=2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.42.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.24)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.13.0)
# Requirement already satisfied: certifi in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: pyproject_hooks in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.4.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.6)
# Requirement already satisfied: sympy in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.73.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.61b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hetvidesai\anaconda3\envs\langchain_env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)

# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_text_splitters.markdown import MarkdownHeaderTextSplitter
from langchain_text_splitters.character import CharacterTextSplitter
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
loader_docx = Docx2txtLoader("Introduction_to_Data_and_Data_Science_2.docx")
pages = loader_docx.load()

md_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on = [("#", "Course Title"), 
                           ("##", "Lecture Title")]
)

pages_md_split = md_splitter.split_text(pages[0].page_content)

for i in range(len(pages_md_split)):
    pages_md_split[i].page_content = ' '.join(pages_md_split[i].page_content.split())
    
char_splitter = CharacterTextSplitter(
    separator = ".",
    chunk_size = 500,
    chunk_overlap  = 50
)

pages_char_split = char_splitter.split_documents(pages_md_split)

embedding = OpenAIEmbeddings(model='text-embedding-ada-002')

# %%
len(pages_char_split)

# %%
vectorstore = Chroma.from_documents(documents = pages_char_split, 
                                    embedding = embedding, 
                                    persist_directory = "./intro-to-ds-lectures")

# %%
vectorstore_from_directory = Chroma(persist_directory = "./intro-to-ds-lectures", 
                                    embedding_function = embedding)
