# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HetviDesai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentence = "Her cat's name is Lune. Her dog's name is Max."

# %%
sent_tokenize(sentence)
# Out:
# ["Her cat's name is Lune.", "Her dog's name is Max."]

# %%
sentence = "her cat's name is luna."
word_tokenize(sentence)
# Out:
# ['her', 'cat', "'s", 'name', 'is', 'luna', '.']

# %%
sentence2 = "Her cat's name is Luna and her dog's name is Mex"
word_tokenize(sentence2)
# Out:
# ['Her',
#  'cat',
#  "'s",
#  'name',
#  'is',
#  'Luna',
#  'and',
#  'her',
#  'dog',
#  "'s",
#  'name',
#  'is',
#  'Mex']
