# %%
pwd
# Out:
# 'C:\\Users\\HetviDesai\\Documents\\Crest Training\\01_Python_Bootcamp\\12_Advanced Python Modules'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HetviDesai\\Documents\\Crest Training\\01_Python_Bootcamp\\12_Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Opening and Reading files.ipynb']

# %%
f = open('text.txt', '+w')

with open('text.txt', '+w') as file:
    f.write('hello')
f.seek(0)
print(f.read())
# Out:
# hello

# %%
for folder , sub_folders , files in os.walk("12_Advanced Python Modules"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')

# %%
import time

def func_one(n):
    '''
    Given a number n, returns a list of string integers
    ['0','1','2',...'n]
    '''
    return [str(num) for num in range(n)]

startTime = time.time()
func_one(100000)

endTime = time.time() - startTime

print(endTime)
# Out:
# 0.044991254806518555

# %%
# %%timeit
func_one(10000)
# Out:
# 2.25 ms ± 395 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import zipfile

f = open("new_file.txt",'w+')
f.write("Here is some text")
f.close()

f = open("new_file2.txt",'w+')
f.write("Here is some text")
f.close()

comp_file = zipfile.ZipFile('comp_file.zip', 'w')
comp_file.write('new_file.txt', compress_type=zipfile.ZIP_DEFLATED)
comp_file.write('new_file2.txt', compress_type = zipfile.ZIP_DEFLATED)

comp_file.close()

# %%
zip_obj = zipfile.ZipFile('comp_file.zip', 'r')
zip_obj.extractall("Extracted Content")
