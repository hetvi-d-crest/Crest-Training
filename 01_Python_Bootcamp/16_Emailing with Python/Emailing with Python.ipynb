# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [103.214.226.180]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
email= getpass.getpass("Enter your email.")
password = getpass.getpass("Enter your password")
smtp_object.login(email, password)
# Out:
# Enter your email. ········
# Enter your password ········
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 email= getpass.getpass("Enter your email.")
#       2 password = getpass.getpass("Enter your password")
# ----> 3 smtp_object.login(email, password)
#
# NameError: name 'smtp_object' is not defined

# %%
from_address = getpass.getpass("Enter your email: ")
to_address = getpass.getpass("Enter the email of the recipient: ")
subject = input("Enter the subject line: ")
message = input("Type out the message you want to send: ")
msg = "Subject: " + subject + '\n' + message
smtp_object.sendmail(from_address,to_address,msg)
# Out:
# Enter your email:  ········
# Enter the email of the recipient:  ········
# Enter the subject line:  Testing Email
# Type out the message you want to send:  Hi this is a test email
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 message = input("Type out the message you want to send: ")
#       5 msg = "Subject: " + subject + '\n' + message
# ----> 6 smtp_object.sendmail(from_address,to_address,msg)
#
# NameError: name 'smtp_object' is not defined

# %%
import imaplib

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

user = input("ENter your email")

password = getpass.getpass("Enter your password")

M.login(user, password)
# Out:
# ENter your email hetvi.d@crestskillserve.com
# Enter your password ········
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 7
#       3 user = input("ENter your email")
#       5 password = getpass.getpass("Enter your password")
# ----> 7 M.login(user, password)
#
# File ~\anaconda3\Lib\imaplib.py:619, in IMAP4.login(self, user, password)
#     617 typ, dat = self._simple_command('LOGIN', user, self._quote(password))
#     618 if typ != 'OK':
# --> 619     raise self.error(dat[-1])
#     620 self.state = 'AUTH'
#     621 return typ, dat
#
# error: b'[AUTHENTICATIONFAILED] Invalid credentials (Failure)'

# %%
M.select('inbox')

M.login()
