# %%
# %load_ext dotenv
# %dotenv

# %%
import langchain
import groq

from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import CommaSeparatedListOutputParser
import os

# %%
chat = ChatGroq(
    model_name="llama-3.1-8b-instant",  # Groq model
    temperature=0,
    max_tokens=200,
    groq_api_key=os.getenv("GROQ_API_KEY"),  # remove if already set globally
)

# %%
message_h = HumanMessage(content = f''' I've recently adopted a dog. Could you suggest some dog names?
{CommaSeparatedListOutputParser().get_format_instructions()}
''')

# %%
print(message_h.content)
# Out:
#  I've recently adopted a dog. Could you suggest some dog names?
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
response = chat.invoke([message_h])
print(response.content)
# Out:
# Congratulations on your new furry family member. Here are some dog name suggestions:
#
# Max, Charlie, Luna, Bella, Rocky, Duke, Lucy, Cooper, Daisy, Buddy, Ginger, Bear, Lola, Molly, Hunter, Sadie, Maggie, Oliver, Abbie, Finn
#
# You can also consider names based on your dog's appearance, personality, or breed. For example, if your dog is a golden retriever, you might consider names like Sunny, Honey, or Goldie. If your dog is small and playful, you might consider names like Pixie, Sparky, or Zoom.
#
# Remember, the most important thing is to choose a name that you and your dog will love and enjoy using.

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed
# Out:
# ['Congratulations on your new furry family member. Here are some dog name suggestions:\n\nMax',
#  'Charlie',
#  'Luna',
#  'Bella',
#  'Rocky',
#  'Duke',
#  'Lucy',
#  'Cooper',
#  'Daisy',
#  'Buddy',
#  'Ginger',
#  'Bear',
#  'Lola',
#  'Molly',
#  'Hunter',
#  'Sadie',
#  'Maggie',
#  'Oliver',
#  'Abbie',
#  "Finn\n\nYou can also consider names based on your dog's appearance",
#  'personality',
#  'or breed. For example',
#  'if your dog is a golden retriever',
#  'you might consider names like Sunny',
#  'Honey',
#  'or Goldie. If your dog is small and playful',
#  'you might consider names like Pixie',
#  'Sparky',
#  'or Zoom.\n\nRemember',
#  'the most important thing is to choose a name that you and your dog will love and enjoy using.']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
