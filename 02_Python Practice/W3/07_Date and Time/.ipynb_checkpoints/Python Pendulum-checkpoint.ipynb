# %%
pip install pendulum
# Out:
# Collecting pendulum
#   Downloading pendulum-3.2.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pendulum) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\hetvidesai\anaconda3\lib\site-packages (from pendulum) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hetvidesai\anaconda3\lib\site-packages (from python-dateutil>=2.6->pendulum) (1.17.0)
# Downloading pendulum-3.2.0-cp313-cp313-win_amd64.whl (258 kB)
# Installing collected packages: pendulum
# Successfully installed pendulum-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# Current Date and Time:
#
# 1. Write a Python program to print the current date and time using Pendulum module

# %%
import pendulum

current = pendulum.now()

print("The current date and time using pendulum : ", current)
# Out:
# The current date and time using pendulum :  2026-02-24 11:57:45.122730+05:30

# %% [raw]
# Manipulate Date and Time:
#
# 2. Write a Python program to create a Pendulum object for tomorrow's date and time using Pendulum module.

# %%
import pendulum

current = pendulum.now()
tomorrow = current.add(days = 1)

print("Tomorrow's date and time : ", tomorrow)
# Out:
# Tomorrow's date and time :  2026-02-25 12:01:00.963441+05:30
