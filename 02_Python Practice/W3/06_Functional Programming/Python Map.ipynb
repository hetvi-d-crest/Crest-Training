# %% [raw]
# 1. Triple Numbers Map
#
# Write a Python program to triple all numbers in a given list of integers. Use Python map.

# %%
def triple(lst):
    print("Original list ", lst)
    res =  map(lambda x : x*3, lst)
    print("Trilpled list using map: ", list(res))
    
triple([1,1,1])
# Out:
# Original list  [1, 1, 1]
# Trilpled list using map:  [3, 3, 3]
