# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DATA/cancer_classification.csv')

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
pwd
# Out:
# 'C:\\Users\\HetviDesai\\Documents\\Crest Training\\07_Python for Data Science and Machine Learning\\19_Neural Nets and Deep Learning'

# %% [markdown]
# ## Creating the Tensorboard Callback
#
# TensorBoard is a visualization tool provided with TensorFlow.
#
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=path_to_your_logs
# ```
#
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#         update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2026-03-27--1743'

# %%
pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (3.8)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (2.3.5)
# Requirement already satisfied: packaging in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (12.0.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (7.34.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (80.9.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hetvidesai\anaconda3\lib\site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\hetvidesai\anaconda3\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hetvidesai\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/5.5 MB 1.3 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.5 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 1.8/5.5 MB 1.6 MB/s eta 0:00:03
#    --------------- ------------------------ 2.1/5.5 MB 1.7 MB/s eta 0:00:03
#    -------------------- ------------------- 2.9/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.9 MB/s  0:00:03
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorboard-data-server, tensorboard
#
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    ---------------------------------------- 2/2 [tensorboard]
#
# Successfully installed tensorboard-2.20.0 tensorboard-data-server-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = 'logs\\fit'

# OPTIONAL: ADD A TIMESTAMP FOR UNIQUE FOLDER
# timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
# log_directory = log_directory + '\\' + timestamp


board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)

# %% [markdown]
# Now create the model layers:

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.6795 - val_loss: 0.6446
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6414 - val_loss: 0.6053
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6228 - val_loss: 0.5723
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5798 - val_loss: 0.5383
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5587 - val_loss: 0.5081
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5637 - val_loss: 0.4843
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5511 - val_loss: 0.4610
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5174 - val_loss: 0.4359
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.4843 - val_loss: 0.4031
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4688 - val_loss: 0.3784
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4480 - val_loss: 0.3597
# Epoch 12/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4455 - val_loss: 0.3433
# Epoch 13/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4082 - val_loss: 0.3235
# Epoch 14/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4068 - val_loss: 0.3064
# Epoch 15/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4084 - val_loss: 0.2945
# Epoch 16/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4064 - val_loss: 0.2832
# Epoch 17/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3906 - val_loss: 0.2748
# Epoch 18/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3367 - val_loss: 0.2581
# Epoch 19/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3482 - val_loss: 0.2466
# Epoch 20/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3277 - val_loss: 0.2365
# Epoch 21/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3028 - val_loss: 0.2186
# Epoch 22/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3078 - val_loss: 0.2145
# Epoch 23/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3103 - val_loss: 0.2079
# Epoch 24/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2993 - val_loss: 0.2071
# Epoch 25/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3014 - val_loss: 0.2021
# Epoch 26/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2898 - val_loss: 0.1928
# Epoch 27/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2845 - val_loss: 0.1929
# Epoch 28/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2833 - val_loss: 0.1865
# Epoch 29/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2798 - val_loss: 0.1780
# Epoch 30/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2671 - val_loss: 0.1786
# Epoch 31/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2653 - val_loss: 0.1763
# Epoch 32/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3006 - val_loss: 0.1719
# Epoch 33/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2648 - val_loss: 0.1722
# Epoch 34/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2612 - val_loss: 0.1631
# Epoch 35/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2579 - val_loss: 0.1577
# Epoch 36/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2292 - val_loss: 0.1581
# Epoch 37/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2553 - val_loss: 0.1493
# Epoch 38/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2428 - val_loss: 0.1475
# Epoch 39/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2039 - val_loss: 0.1421
# Epoch 40/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2109 - val_loss: 0.1390
# Epoch 41/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1888 - val_loss: 0.1363
# Epoch 42/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2025 - val_loss: 0.1314
# Epoch 43/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2158 - val_loss: 0.1313
# Epoch 44/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1951 - val_loss: 0.1291
# Epoch 45/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2255 - val_loss: 0.1324
# Epoch 46/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2001 - val_loss: 0.1297
# Epoch 47/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1998 - val_loss: 0.1301
# Epoch 48/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2035 - val_loss: 0.1287
# Epoch 49/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2025 - val_loss: 0.1264
# Epoch 50/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1865 - val_loss: 0.1248
# Epoch 51/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2012 - val_loss: 0.1199
# Epoch 52/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2013 - val_loss: 0.1198
# Epoch 53/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1652 - val_loss: 0.1178
# Epoch 54/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1650 - val_loss: 0.1160
# Epoch 55/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1853 - val_loss: 0.1138
# Epoch 56/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1722 - val_loss: 0.1195
# Epoch 57/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1819 - val_loss: 0.1161
# Epoch 58/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1505 - val_loss: 0.1098
# Epoch 59/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1613 - val_loss: 0.1101
# Epoch 60/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1594 - val_loss: 0.1122
# Epoch 61/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1601 - val_loss: 0.1155
# Epoch 62/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.1663 - val_loss: 0.1072
# Epoch 63/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1466 - val_loss: 0.1092
# Epoch 64/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1588 - val_loss: 0.1024
# Epoch 65/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1353 - val_loss: 0.1142
# Epoch 66/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1601 - val_loss: 0.1071
# Epoch 67/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1520 - val_loss: 0.1033
# Epoch 68/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1512 - val_loss: 0.1081
# Epoch 69/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1465 - val_loss: 0.1075
# Epoch 70/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1409 - val_loss: 0.1062
# Epoch 71/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1326 - val_loss: 0.1031
# Epoch 72/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1472 - val_loss: 0.1025
# Epoch 73/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1500 - val_loss: 0.1015
# Epoch 74/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1215 - val_loss: 0.1040
# Epoch 75/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1300 - val_loss: 0.1013
# Epoch 76/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1213 - val_loss: 0.0999
# Epoch 77/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1284 - val_loss: 0.1019
# Epoch 78/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1229 - val_loss: 0.1013
# Epoch 79/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1318 - val_loss: 0.1014
# Epoch 80/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1372 - val_loss: 0.1034
# Epoch 81/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1114 - val_loss: 0.0983
# Epoch 82/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1309 - val_loss: 0.1043
# Epoch 83/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1073 - val_loss: 0.0960
# Epoch 84/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1570 - val_loss: 0.0992
# Epoch 85/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1272 - val_loss: 0.1081
# Epoch 86/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1126 - val_loss: 0.0960
# Epoch 87/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1256 - val_loss: 0.0962
# Epoch 88/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1309 - val_loss: 0.1011
# Epoch 89/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1182 - val_loss: 0.1025
# Epoch 90/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1140 - val_loss: 0.0962
# Epoch 91/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1230 - val_loss: 0.1052
# Epoch 92/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1099 - val_loss: 0.1093
# Epoch 93/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1127 - val_loss: 0.1073
# Epoch 94/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1136 - val_loss: 0.0918
# Epoch 95/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0992 - val_loss: 0.1027
# Epoch 96/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1032 - val_loss: 0.0982
# Epoch 97/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1060 - val_loss: 0.1077
# Epoch 98/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1100 - val_loss: 0.1046
# Epoch 99/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0962 - val_loss: 0.0964
# Epoch 100/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0904 - val_loss: 0.0936
# Epoch 101/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1102 - val_loss: 0.1040
# Epoch 102/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1029 - val_loss: 0.0942
# Epoch 103/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0798 - val_loss: 0.0954
# Epoch 104/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1116 - val_loss: 0.1029
# Epoch 105/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1142 - val_loss: 0.1057
# Epoch 106/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1088 - val_loss: 0.1011
# Epoch 107/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.1147 - val_loss: 0.0989
# Epoch 108/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1037 - val_loss: 0.0988
# Epoch 109/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1081 - val_loss: 0.1110
# Epoch 110/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1098 - val_loss: 0.0901
# Epoch 111/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1056 - val_loss: 0.0982
# Epoch 112/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1165 - val_loss: 0.0915
# Epoch 113/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1027 - val_loss: 0.0963
# Epoch 114/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0992 - val_loss: 0.0928
# Epoch 115/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1320 - val_loss: 0.0916
# Epoch 116/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1038 - val_loss: 0.0919
# Epoch 117/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1063 - val_loss: 0.1069
# Epoch 118/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0837 - val_loss: 0.0983
# Epoch 119/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0896 - val_loss: 0.0925
# Epoch 120/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1151 - val_loss: 0.0955
# Epoch 121/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0920 - val_loss: 0.0970
# Epoch 122/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1048 - val_loss: 0.1191
# Epoch 123/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0962 - val_loss: 0.0913
# Epoch 124/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0981 - val_loss: 0.0925
# Epoch 125/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0880 - val_loss: 0.1133
# Epoch 126/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0789 - val_loss: 0.0921
# Epoch 127/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1041 - val_loss: 0.0977
# Epoch 128/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0926 - val_loss: 0.0896
# Epoch 129/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0999 - val_loss: 0.0898
# Epoch 130/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0724 - val_loss: 0.0894
# Epoch 131/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0837 - val_loss: 0.0962
# Epoch 132/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0850 - val_loss: 0.0936
# Epoch 133/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0662 - val_loss: 0.0937
# Epoch 134/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0981 - val_loss: 0.1071
# Epoch 135/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0853 - val_loss: 0.0943
# Epoch 136/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0871 - val_loss: 0.0987
# Epoch 137/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0705 - val_loss: 0.0989
# Epoch 138/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0804 - val_loss: 0.0986
# Epoch 139/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0926 - val_loss: 0.1017
# Epoch 140/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0916 - val_loss: 0.0901
# Epoch 141/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0854 - val_loss: 0.0926
# Epoch 142/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0857 - val_loss: 0.1002
# Epoch 143/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1010 - val_loss: 0.0968
# Epoch 144/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0940 - val_loss: 0.0904
# Epoch 145/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1035 - val_loss: 0.0898
# Epoch 146/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1000 - val_loss: 0.0981
# Epoch 147/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0862 - val_loss: 0.0966
# Epoch 148/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0810 - val_loss: 0.0896
# Epoch 149/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0864 - val_loss: 0.0914
# Epoch 150/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0924 - val_loss: 0.1062
# Epoch 151/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0765 - val_loss: 0.0964
# Epoch 152/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0808 - val_loss: 0.0912
# Epoch 153/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0806 - val_loss: 0.0950
# Epoch 154/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0813 - val_loss: 0.0879
# Epoch 155/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0934 - val_loss: 0.1015
# Epoch 156/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0907 - val_loss: 0.1004
# Epoch 157/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0891 - val_loss: 0.0908
# Epoch 158/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0918 - val_loss: 0.0940
# Epoch 159/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0856 - val_loss: 0.0926
# Epoch 160/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0695 - val_loss: 0.0923
# Epoch 161/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0743 - val_loss: 0.0926
# Epoch 162/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0907 - val_loss: 0.1041
# Epoch 163/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0977 - val_loss: 0.1007
# Epoch 164/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0852 - val_loss: 0.0842
# Epoch 165/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0844 - val_loss: 0.0836
# Epoch 166/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0921 - val_loss: 0.1042
# Epoch 167/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0627 - val_loss: 0.0943
# Epoch 168/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1047 - val_loss: 0.0920
# Epoch 169/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0848 - val_loss: 0.0997
# Epoch 170/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0958 - val_loss: 0.1067
# Epoch 171/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0805 - val_loss: 0.0853
# Epoch 172/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0891 - val_loss: 0.0889
# Epoch 173/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0688 - val_loss: 0.0963
# Epoch 174/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0911 - val_loss: 0.0994
# Epoch 175/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0767 - val_loss: 0.0889
# Epoch 176/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0779 - val_loss: 0.1003
# Epoch 177/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0802 - val_loss: 0.0993
# Epoch 178/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0632 - val_loss: 0.1175
# Epoch 179/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0863 - val_loss: 0.1119
# Epoch 180/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0731 - val_loss: 0.0941
# Epoch 181/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0928 - val_loss: 0.0907
# Epoch 182/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0694 - val_loss: 0.0964
# Epoch 183/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0802 - val_loss: 0.0957
# Epoch 184/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0656 - val_loss: 0.0935
# Epoch 185/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0782 - val_loss: 0.0995
# Epoch 186/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0692 - val_loss: 0.1029
# Epoch 187/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0878 - val_loss: 0.0913
# Epoch 188/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0792 - val_loss: 0.1015
# Epoch 189/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0740 - val_loss: 0.1162
# Epoch 190/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0759 - val_loss: 0.1133
# Epoch 190: early stopping

# %% [markdown]
# # Running Tensorboard

# %% [markdown]
# ## Running through the Command Line
#
# **Watch video to see how to run Tensorboard through a command line call.**

# %% [markdown]
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)

# %%
print(log_directory)
# Out:
# logs\fit

# %%
pwd
# Out:
# 'C:\\Users\\HetviDesai\\Documents\\Crest Training\\07_Python for Data Science and Machine Learning\\19_Neural Nets and Deep Learning'

# %% [markdown]
# ### Use cd at your command line to change directory to the file path reported back by pwd or your current .py file location.
# ### Then run this code at your command line or terminal

# %%
tensorboard --logdir logs\fit
# Out:
#   Cell In[25], line 1
#     tensorboard --logdir logs\fit
#                               ^
# SyntaxError: unexpected character after line continuation character
