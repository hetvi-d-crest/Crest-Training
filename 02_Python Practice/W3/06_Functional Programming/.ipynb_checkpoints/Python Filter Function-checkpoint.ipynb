# %% [raw]
# Even Number Filter
#
# Write a Python function that filters out even numbers from a list of integers using the filter function.

# %%
def get_even(lst):
    return filter(lambda x : x%2 == 0, lst)

res = get_even([1,2,3,4,5])
print(list(res))
# Out:
# [2, 4]
