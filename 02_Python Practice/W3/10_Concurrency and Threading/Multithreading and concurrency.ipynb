# %% [raw]
# 1. Multiple Threads Creation
#
# Write a Python program to create multiple threads and print their names.

# %%
import threading
def print_thread():
    print("Current thread: ", threading.current_thread().name)

threads = []

for i in range(5):
    thread = threading.Thread(target = print_thread)
    threads.append(thread)
    thread.start()

for thread in threads:
    thread.join()
# Out:
# Current thread:  Thread-13 (print_thread)
# Current thread:  Thread-14 (print_thread)
# Current thread:  Thread-15 (print_thread)
# Current thread:  Thread-16 (print_thread)
# Current thread:  Thread-17 (print_thread)

# %% [raw]
# 2. Concurrent File Downloader
#
# Write a Python program to download multiple files concurrently using threads.

# %%
import threading
import urllib.request
def download_file(url, filename):
    print(f'Downloading from {url} : {filename}\n')
    urllib.request.urlretrieve(url, filename)
    print(f'{filename} downloaded successfully\n')

files_to_download = [
    {"url": "https://en.wikipedia.org/wiki/British_logistics_in_the_Normandy_campaign", "filename": "i:\wfile1"},
    {"url": "https://en.wikipedia.org/wiki/Graph_(abstract_data_type)", "filename": "i:\Graph_abstract_data_type"},
    {"url": "https://example.com/", "filename": "i:\example"}
]

threads = []

for file_info in files_to_download:
    thread = threading.Thread(
        target = download_file,
        args = (file_info["url"], file_info["filename"])
    )
    thread.start()
    threads.append(thread)

for thread in threads:
    thread.join()
# Out:
# Downloading from https://en.wikipedia.org/wiki/British_logistics_in_the_Normandy_campaign : i:\wfile1
#
# Downloading from https://en.wikipedia.org/wiki/Graph_(abstract_data_type) : i:\Graph_abstract_data_type
#
# Downloading from https://example.com/ : i:\example
# Exception in thread Thread-9 (download_file):
# Traceback (most recent call last):
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\AppData\Local\Temp\ipykernel_5936\2982825653.py", line 5, in download_file
#     urllib.request.urlretrieve(url, filename)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 214, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#                             ~~~~~~~^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 189, in urlopen
#     return opener.open(url, data, timeout)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 495, in open
#     response = meth(req, response)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 604, in http_response
#     response = self.parent.error(
#         'http', request, response, code, msg, hdrs)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 533, in error
#     return self._call_chain(*args)
#            ~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 613, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-11 (download_file):
# Traceback (most recent call last):
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\AppData\Local\Temp\ipykernel_5936\2982825653.py", line 5, in download_file
#     urllib.request.urlretrieve(url, filename)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 224, in urlretrieve
#     tfp = open(filename, 'wb')
# FileNotFoundError: [Errno 2] No such file or directory: 'i:\\example'
# Exception in thread Thread-10 (download_file):
# Traceback (most recent call last):
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\AppData\Local\Temp\ipykernel_5936\2982825653.py", line 5, in download_file
#     urllib.request.urlretrieve(url, filename)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 214, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#                             ~~~~~~~^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 189, in urlopen
#     return opener.open(url, data, timeout)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 495, in open
#     response = meth(req, response)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 604, in http_response
#     response = self.parent.error(
#         'http', request, response, code, msg, hdrs)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 533, in error
#     return self._call_chain(*args)
#            ~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\HetviDesai\anaconda3\Lib\urllib\request.py", line 613, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
