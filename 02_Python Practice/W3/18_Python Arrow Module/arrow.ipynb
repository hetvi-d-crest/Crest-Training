# %%
pip install arrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# 1. Write a Python program to get the current UTC datetime, local datetime and datetime of a given location using arrow module.

# %%
import arrow
a = arrow.utcnow()
print(a)
# Out:
# 2026-02-26T06:45:26.458248+00:00

# %%
b = arrow.now()
print(b)
# Out:
# 2026-02-26T12:15:41.164065+05:30

# %%
c= arrow.now('US/Pacific')
print(c)
# Out:
# 2026-02-25T22:46:40.505122-08:00

# %%
from datetime import datetime
from dateutil import tz
print("Create a date from a given date and a given time zone")
date1 = arrow.get(datetime(2024, 7, 12), 'US/Pacific')
print(date1)
# Out:
# Create a date from a given date and a given time zone
# 2024-07-12T00:00:00-07:00

# %%
d2 = arrow.get(datetime(2017, 7, 5), tz.gettz('America/Chicago'))
print(d2)
# Out:
# 2017-07-05T00:00:00-05:00

# %%
d3 = arrow.get(datetime.now(tz.gettz('US/Pacific')))
print("\nCreate a date using current datetime and a specified time zone:")
print(d3)
# Out:
# Create a date using current datetime and a specified time zone:
# 2026-02-25T22:58:19.359365-08:00
