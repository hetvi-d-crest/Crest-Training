# %% [raw]
# 1. Employee NamedTuple
#
# Write a Python program that defines a NamedTuple called Employee with fields like name, age, and country. Print each employee's name and country.

# %%
from collections import namedtuple
Person = namedtuple("Person", ["Name", "Age", "Country"])

def main():
    try:
        people = [
            Person("Klaes Susana", 35, "USA"),
            Person("Auxentius Cloe", 44, "Canada"),
            Person("Golzar Merob", 28, "UK"),
            Person("Tatjana Adhelm", 30, "Australia"),
        ]
        for person in people:
            print("Person's name: ", person.Name)
            print("Person's country: ", person.Country)
            print()

    except Exception as e:
        print("An error occured!", e)

if __name__ == "__main__":
    main()
# Out:
# Person's name:  Klaes Susana
# Person's country:  USA
#
# Person's name:  Auxentius Cloe
# Person's country:  Canada
#
# Person's name:  Golzar Merob
# Person's country:  UK
#
# Person's name:  Tatjana Adhelm
# Person's country:  Australia
