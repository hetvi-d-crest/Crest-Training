# %% [raw]
# Even/Odd Checker
#
# Write a Python program to check if a given number is even or odd using boolean variables.

# %%
def check(num):
    is_even = False
    if num % 2 == 0:
       is_even = True
    return is_even

# %%
check(5)
# Out:
# False

# %%
check(10)
# Out:
# True
