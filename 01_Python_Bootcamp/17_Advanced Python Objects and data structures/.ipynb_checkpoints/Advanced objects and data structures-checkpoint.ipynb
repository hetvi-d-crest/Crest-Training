# %%
hex(900)
# Out:
# '0x384'

# %%
hex(2)
# Out:
# '0x2'

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(1)
# Out:
# '0b1'

# %%
pow(2, 3)
# Out:
# 8

# %%
round(-4, 2)
# Out:
# -4

# %%
round(-395, 2)
# Out:
# -395

# %%
round(4, -2)
# Out:
# 0

# %%
round(395, -2)
# Out:
# 400

# %%
s= "hello world"

s.split('e')
# Out:
# ['h', 'llo world']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo world')

# %%
s1 = {1,2,3,4}
s2 = {1,2,3}

s1.difference(s2)
# Out:
# {4}

# %%
s2.difference(s1)
# Out:
# set()

# %%
s1.discard(4)

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.remove(2)

# %%
s1
# Out:
# {1, 3}

# %%
{x:x**2 for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
x= [1,2,3]
x.append([4,5])
x.extend([6])

# %%
x
# Out:
# [1, 2, 3, [4, 5], 6]
